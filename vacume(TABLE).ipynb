# %%
import random 
class enviroment():
    def __init__(self):
        self.location = { 'A':'0', 'B':'0'}
        self.location['A'] = random.randint( 0 , 1)
        self.location['B'] = random.randint( 0 , 1)

# %%
class table_driven(enviroment):
    def __init__(self ,enviroment):
        
      #  print(enviroment.location)
        
        cost = 0
        
        vacume_location = random.randint('A' , 'B')
        
        table = { ('A', 1): 0 ,
                  ('B', 1): 0,
                  ('A' , 0): "move left",
                  ('B' , 0 ): "move right"
                }
        
        if vacume_location == "A":
            for i in table:
                if i[0][0] == "A":
                    if environment.location['A'] == 1:
                        print('Location A is Dirty')
                        
                        environment.location['A'] == 0
                        cost -= 1
                        print('Location A has been CLeaned')  
                        print('Moving to Location B')
                        cost += 1
                        
                        if environment.location['B'] == 1:
                            print('Location B is Dirty')
                            
                            environment.location['B'] == 0
                            cost -= 1
                            
                            print('Location B has been Cleaned')
                            return
                        
                        
                    if environment.location['A'] == 0:
                        cost += 1
                        print('Moving to B') 
                        
                        if environment.location['B'] == 1:
                            print('Location B is Dirty')
                            
                            environment.location['B'] == 0
                            cost -= 1
                            
                            print('Location B has been Cleaned')
                        return
                    
                    
                    
                    
                    
            if vacuumlocation == "B":
                print('VAcuum is randomly placed at B')
            
                for i in table:
                    if i[0][0] == 'B':
                        
                        if environment.location['B'] == 1:
                            print('Location B is Dirty')
                        
                            environment.location['B'] == 0
                            cost -= 1
                            print('Location B has been CLeaned')
                        
                            print('Moving to Location A')
                            cost += 1
                        
                            if environment.location['A'] == 1:
                                print('Location A is Dirty')
                            
                                environment.location['A'] == 0
                                cost -= 1
                            
                                print('Location A has been Cleaned')
                                return
                        
                        
                    
                            
                    if environment.location['B'] == 0:
                        cost += 1
                        print('Moving to A towards ')
                        
                        if environment.location['A'] == 1:
                            print('Location A is Dirty')
                            
                            environment.location['A'] == 0
                            cost -= 1
                            
                            print('Location A has been Cleaned')
                        return
        

                
            
        
        
        
        print(environment.location)
        costt = str(cost)
        print('total cost for cleaning : ' + str(costt))

# %%
e = enviroment()

# %%
able = { ('A', 1): 0 ,
                ('B', 1): 0,
                ('A' , 0): "move left",
                ('B' , 0 ): "move right"
              }
